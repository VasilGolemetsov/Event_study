# %%
import yfinance as yf
import pandas as pd
from pandas_datareader import data
import pandas_datareader as web
import eventstudy as es
import statsmodels.api as sm
import matplotlib.pyplot as plt
import scipy.stats as ss
from scipy.stats import norm
from numpy import sqrt, abs
from datetime import date, datetime, timedelta
import numpy as np
from statistics import NormalDist
from pyxll import xl_func, plot

combined_data = pd.DataFrame()

tickers2 = pd.read_csv("tickers2.csv").drop(["Headqurter"], axis=1).dropna(axis='rows') # import tickers
sectors = list(tickers2['Sector'].unique()) # returns all the unique industries and removes the last nan valeu

for k in range(len(sectors)):

    
    tic = list(tickers2[tickers2['Sector']==sectors[k]]['Ticker']) # returns all the tickers based on an industry
    # tic.extend(['VGOV.L','^FTLC'])
    le = 14 # days before day 0
    ue = 43 # days after day 0
    event_date = datetime(2016,6,24) # event date 
    start = (event_date - timedelta(days=le)).strftime('%Y-%m-%d')  #start date for event perion plus change of date format
    # start = start.strftime('%Y-%m-%d') 
    end = (event_date + timedelta(days=ue)).strftime('%Y-%m-%d') #end date for event perion plus change of date format
    # end = end.strftime('%Y-%m-%d')
    start_date = "2015-01-01" # start date for estimation period
    end_date = (event_date - timedelta(days=le+1)).strftime('%Y-%m-%d') # end date for estimation period


    rf = yf.download('VGOV.L', start=start_date, end=end_date, interval='1d')['Adj Close'] # download a 10 year gilt data for estimation period
    market = yf.download('^FTLC', start=start_date, end=end_date, interval='1d')['Adj Close'] # download market data for estimation period FTSE 350


    rf = pd.DataFrame(rf).pct_change()[1:] # calculate pct_change for rf
    market = pd.DataFrame(market).pct_change()[1:] # calculate pct_change for market

    rf.columns = ['rf'] # rename rf column
    market.columns = ['market'] # rename market column

    returns = yf.download(tic, start_date, end_date, interval = "1d")["Adj Close"] # Download Estimation Period Data 
    # market_returns = web.get_data_yahoo("^IXIC", start_date, end_date, interval = 'd').pct_change()[1:]['Close']
    # risk_free_returns = web.get_data_yahoo('^TNX', start_date, end_date, interval = 'd').pct_change()[1:]['Close']
    # returns = pd.DataFrame(returns).pct_change()[1:]
    # returns = returns.drop("AAF.L", axis=1).pct_change()[1:]
    # returns = returns.pct_change()[1:]
    rows = returns.shape[0] # number of rows
    returns.index = pd.to_datetime(returns.index, format = '%d/%m/%Y').strftime('%Y-%m-%d') # change row date format


    # rf = pd.read_csv("10y.csv")
    # rf.index = list(rf['Date'])
    # rf

    pd.set_option("display.max_rows", 20) # change max display of rows
    pd.set_option("display.max_columns", None) # change max display of columns
    isn = dict(returns.isnull().mean().transpose()) # check how many null values are there column wise 
    for sym, val in isn.items():
        if returns.shape[0]==rows and val>0: # loop to check whether dates are the same number and if there are null values in the dataset
            returns.drop([sym],axis=1,inplace=True) # if found drops corresponding ticker
        
        # print(sym, val)

    returns = returns.pct_change()[1:] # returns of the dataset


    for i in range(len(returns.columns[:])): # loop to get excess returns r(it)-E[rf]
        returns[returns.columns[i]] = returns[returns.columns[i]] - rf['rf'].mean()
    returns.dropna()
    returns = returns.dropna() # drops na values
    x = market['market'] # independent variable for regression
    x_sm = sm.add_constant(x) # add constant
    values = pd.DataFrame(index=['0','1'], columns=list(returns.columns)[:]) # create dataframe to store alpha and beta 

    for i in range(len(returns.columns[:])): # run regression and store alpha and beta in values dataframe 0=alpha, 1=beta
        returns = returns.dropna()
        y = list(returns[returns.columns[i]])
        model = sm.OLS(y,x_sm)
        results = model.fit()
        values.iat[0,i] = results.params[0]
        values.iat[1,i] = results.params[1]
    

    ls = list(returns.columns) # return a list of columns from returns dataframe (tickers)
    ls.append('^FTLC')
    event = yf.download(ls,start, end, interval='1d').pct_change()[1:]['Adj Close'] # download event data for tickers and market 
    event.index = pd.to_datetime(event.index, format = '%d/%m/%Y').strftime('%Y-%m-%d')
    # if event.shape[0]%2==0:
    ix = np.arange(-int(event.index.get_loc('2016-06-24')),int(int(event.shape[0] - event.index.get_loc('2016-06-24')))) # change dates to a day timeframe counting down to 0(event day) and up after the event
    event.index = ix # change event dataframe index to countdown




    event.isna().values.any()


    ar_returns = pd.DataFrame(index = ix, columns =list(event.columns)) # create abnormal returns dataframe
    for i in range(len(event.columns[:-1])):
        returns = returns.dropna()
        ar_returns[event.columns[i]] = event[event.columns[i]] - (values.iat[0,i] + values.iat[1,i]*event['^FTLC']) #calculates abnormal returns (stock returns - normal returns )

    ar_returns.std(axis=0)
    asd = ar_returns/ar_returns.std(axis=0)

    ar_returns.describe()
    ar_returns.drop(['^FTLC'], axis=1, inplace=True) # removes market data column
    aar = ar_returns.mean(axis=1) # calculates the average of the rows
    aar = pd.DataFrame(aar,columns = ['AAR']) #creates dataframe of aar

    plt.close("all")

    car = pd.DataFrame(index = ix, columns =list(event.columns[:-1])) # create car dataframe

    for i in range(len(event.columns[:-1])):
        returns = returns.dropna()
        car[event.columns[i]] = ar_returns[returns.columns[i]].cumsum() # calculates car values 
    i = (ar_returns.var(axis=0)/(20**2)).sum()

    caar = pd.DataFrame(car.mean(axis=1), columns=['CAAR']) # creates caar dataframe and calculates caar

    # caar['Variance'] = car.var(axis=1)
    # caar['t-stat'] = (caar['CAAR']/(caar['Variance']**(1/2)))*(float(car.shape[1])**(1/2))
    caar['Variance'] = ""
    for i in range(len(ar_returns.index)): # calculates variance of caar
        caar.iat[i,1]=((ar_returns.var(axis=0).sum())/(ar_returns.shape[1]**2))*(caar.index[i]-caar.index[0]+1) 
    caar = caar.astype(float) # changes values to float 
    
    caar['t-stat'] = (caar['CAAR']/(caar['Variance']**(1/2))) # calculates t-stat for caar
    caar['p-value'] = norm.cdf(caar['t-stat']) # calculates p-value for caar
    # caar['p-value'] = ss.t.sf(abs(caar['t-stat']),float(caar.shape[1]-2))
    caar['Significance'] = ""
    for i in range(len(caar.index)): # adds asterics for signifficance
        if caar.iat[i,3]<=0.001:
            caar.iat[i,4]="***"
        elif 0.001<caar.iat[i,3]<=0.01:
            caar.iat[i,4]="**"
        elif 0.01<caar.iat[i,3]<=0.05:
            caar.iat[i,4]="*"
        else:
            caar.iat[i,4]=""
    caar['95% CI'] = ""
    for i in range(len(ar_returns.index)): # calculates 95% Confidence Interval
        caar.iat[i,5] = NormalDist(mu=0, sigma=sqrt(caar.iat[i,1])).inv_cdf(0.05)
    caar['99% CI'] = ""
    for i in range(len(ar_returns.index)): # Calculates 99% Confidence Interval
        caar.iat[i,6] = NormalDist(mu=0, sigma=sqrt(caar.iat[i,1])).inv_cdf(0.01)



    aar['Variance'] = ar_returns.var(axis=1) # calculates variance of aar 
    aar['t-stat'] = (aar['AAR']/(aar['Variance']**(1/2)))*(float(car.shape[1])**(1/2)) # calculates t-stat for aar
    # aar['p-value'] = ss.t.sf(abs(aar['t-stat']),float(car.shape[1]-2))
    aar['p-value'] = norm.cdf(aar['t-stat']) # calculates p-value for aar
    aar['Significance'] = ""
    for i in range(len(aar.index)): # adds asterics for signifficance
        if aar.iat[i,3]<=0.001:
            aar.iat[i,4]="***"
        elif 0.001<aar.iat[i,3]<=0.01:
            aar.iat[i,4]="**"
        elif 0.01<aar.iat[i,3]<=0.05:
            aar.iat[i,4]="*"
        else:
            aar.iat[i,4]=""

    pd.set_option("display.max_columns", None)
    # pd.set_option("display.max_rows", 15)
    data = pd.concat([aar,caar], axis=1) # combines aar and caar together
    data.transpose()
    # data.to_latex('main.tex')
    fig, ax = plt.subplots()
    ax.axvline(x=0, color='r', linestyle=(0,(5,10)), label='X = 0')# plot dashed line for x=0
    ax.axhline(y=0, color='r', linestyle=(0,(5,10)), label='Y = 0')# plot dashed line for y=0
    # plt.scatter(aar.index.values,aar['AAR'],s=30,label='AAR')
    # plt.plot(aar.index.values,aar['AAR'],linestyle='solid',linewidth=3)
    # plt.scatter(aar.index.values,caar['CAAR'],s=30,label='CAAR')
    ax.plot(caar.index.values,caar['CAAR'],linewidth=1.5, label='CAAR')#plots caar values 
    ax.plot(caar.index.values,caar['95% CI'],linewidth=1.5, linestyle='dashed', color='grey', label='95% CI') # plots 95% CI
    ax.plot(caar.index.values,caar['99% CI'],linewidth=1.5, linestyle='dashed', color='black', label='99% CI')# plots 95% CI
    ax.legend(fancybox=True) # fancybox for index
    ax.set_xlabel("Event Window") # label x axis
    ax.set_ylabel("CAAR") # label y axis
    ax.set_title(f'Cumulative Abnormal Returns {sectors[k]} Sector') # label table
    ax.grid() # add grid to table
    plt.show()
    fig.savefig(fname=f'Cumulative Abnormal Returns {sectors[k]} Sector.png')

    #Nonparametric data
    returnsNP = yf.download(ls, start, end, interval = "1d")["Adj Close"] # Download Estimation Period Data 
    rows = returnsNP.shape[0] # number of rows
    returnsNP.index = pd.to_datetime(returnsNP.index, format = '%d/%m/%Y').strftime('%Y-%m-%d') # change row date format

    isn = dict(returnsNP.isnull().mean().transpose()) # check how many null values are there column wise 
    for sym, val in isn.items():
        if returnsNP.shape[0]==rows and val>0: # loop to check whether dates are the same number and if there are null values in the dataset
            returnsNP.drop([sym],axis=1,inplace=True) # if found drops corresponding ticker
        
        
    returnsNP = returnsNP.pct_change()[1:]
    returnsNP.index = np.arange(-returnsNP.shape[0]+(returnsNP.shape[0]-1-returnsNP.index.get_loc('2016-06-24')+1),returnsNP.shape[0]-1-returnsNP.index.get_loc('2016-06-24')+1,dtype=object)

    ar_returns = pd.DataFrame(index = list(returnsNP.index), columns =list(returnsNP.columns)) # create abnormal returns dataframe
    for i in range(len(ar_returns.columns[:-1])):
        returnsNP = returnsNP.dropna()
        ar_returns[ar_returns.columns[i]] = returnsNP[ar_returns.columns[i]] - (values.iat[0,i] + values.iat[1,i]*returnsNP['^FTLC']) #calculates abnormal returns (stock returns - normal returns )

    ar_returns.drop(['^FTLC'], axis=1, inplace=True) # removes market data column

    ar_returns_sign = pd.DataFrame(index = list(ar_returns.index), columns =['t-sign', 'p-value', '95% CI','99% CI'])

    ar_returns = ar_returns.transpose()

    ar_returns_sign = ar_returns_sign.transpose()
    for i in range(len(ar_returns_sign.columns)):
        ar_returns_sign.iat[ar_returns_sign.index.get_loc('t-sign'),i] = ((len(ar_returns[ar_returns[ar_returns.columns[i]]>0.0])/(ar_returns.shape[0]))-0.5)*(sqrt(ar_returns.shape[0])/0.5)
        ar_returns_sign.iat[ar_returns_sign.index.get_loc('p-value'),i] = norm.cdf(ar_returns_sign.iat[0,i])
        ar_returns_sign.iat[ar_returns_sign.index.get_loc('95% CI'),i] = NormalDist(mu=0, sigma=1).inv_cdf(0.05)
        ar_returns_sign.iat[ar_returns_sign.index.get_loc('99% CI'),i] =NormalDist(mu=0, sigma=1).inv_cdf(0.01)
        
    ar_returns_sign = ar_returns_sign.transpose()
    ar_returns_sign = ar_returns_sign.astype(float)


    fig, ax = plt.subplots()
    ax.axvline(x=0, color='r', linestyle=(0,(5,10)), label='X = 0')# plot dashed line for x=0
    ax.axhline(y=0, color='r', linestyle=(0,(5,10)), label='Y = 0')# plot dashed line for y=0
    ax.plot(caar.index.values,ar_returns_sign['t-sign'],linewidth=1.5, label='t-sign')#plots caar values 
    ax.plot(caar.index.values,ar_returns_sign['95% CI'],linewidth=1.5, linestyle='dashed', color='grey', label='95% CI') # plots 95% CI
    ax.plot(caar.index.values,ar_returns_sign['99% CI'],linewidth=1.5, linestyle='dashed', color='black', label='99% CI')# plots 95% CI
    ax.legend(fancybox=True) # fancybox for index
    ax.set_xlabel("Event Window") # label x axis
    ax.set_ylabel("t-sign") # label y axis
    ax.set_title(f'Cowan Sign-Test {sectors[k]} Sector') # label table
    ax.grid() # add grid to table
    plt.show()
    fig.savefig(fname=f'Cowan Sign-Test {sectors[k]} Sector.png')
    rank = ar_returns.rank(axis=1)

    ar_returns_rank = pd.DataFrame(columns = rank.columns.tolist(), index= ['rank', 's(rank)', 't-rank', 'p-value','95% CI','99% CI'])

    for i in range(ar_returns_rank.shape[1]):
        ar_returns_rank.iat[ar_returns_rank.index.get_loc('rank'),i] = (rank[rank.columns[i]].sum()-(rank.shape[0]*(rank.shape[1]+1)/2))/(rank.shape[0])
        ar_returns_rank.iat[ar_returns_rank.index.get_loc('s(rank)'),i] = sqrt((ar_returns_rank.pow(2, axis=1).sum(axis=1)[0])/(rank.shape[0]))
        ar_returns_rank.iat[ar_returns_rank.index.get_loc('t-rank'),i] = ar_returns_rank.iat[0,i]/ar_returns_rank.iat[1,i]
        ar_returns_rank.iat[ar_returns_rank.index.get_loc('p-value'),i] = norm.cdf(ar_returns_rank.iat[2,i])
        ar_returns_rank.iat[ar_returns_rank.index.get_loc('95% CI'),i] = NormalDist(mu=0, sigma=1).inv_cdf(0.05)
        ar_returns_rank.iat[ar_returns_rank.index.get_loc('99% CI'),i] =NormalDist(mu=0, sigma=1).inv_cdf(0.01)
    ar_returns_rank = ar_returns_rank.transpose()


 

    fig, ax = plt.subplots()
    ax.axvline(x=0, color='r', linestyle=(0,(5,10)), label='X = 0')# plot dashed line for x=0
    ax.axhline(y=0, color='r', linestyle=(0,(5,10)), label='Y = 0')# plot dashed line for y=0
    ax.plot(caar.index.values,ar_returns_rank['t-rank'],linewidth=1.5, label='t-rank')#plots caar values 
    ax.plot(caar.index.values,ar_returns_rank['95% CI'],linewidth=1.5, linestyle='dashed', color='grey', label='95% CI') # plots 95% CI
    ax.plot(caar.index.values,ar_returns_rank['99% CI'],linewidth=1.5, linestyle='dashed', color='black', label='99% CI')# plots 95% CI
    ax.legend(fancybox=True) # fancybox for index
    ax.set_xlabel("Event Window") # label x axis
    ax.set_ylabel("t-rank") # label y axis
    ax.set_title(f'Corrado Rank-Test {sectors[k]} Sector') # label table
    ax.grid() # add grid to table
    plt.show()
    fig.savefig(fname=f'Corrado Rank-Test {sectors[k]} Sector.png')
    #Nonparametric data
    # caar= pd.concat([caar,ar_returns_rank,ar_returns_sign],axis=0, ignore_index=True)

    # combined_data = pd.concat([combined_data,caar['t-stat'][7:14],caar['Significance'][7:14],ar_returns_rank['t-rank'][7:14],ar_returns_rank['Significance'][7:14],ar_returns_sign['t-sign'][7:14],ar_returns_sign['Significance'][7:14]], axis=1, ignore_index=False)
    # combined_data.to_csv('123.csv', mode='a', index=True,header=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  26 of 26 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  25 of 25 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  71 of 71 completed
#
# 15 Failed downloads:
# - SBDS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - IMMO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - LBG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - GILD.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - DNM.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SEEN.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - TM17.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - OTMP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - PEBB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - HTWS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - TMO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - MIRI.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - NWOR.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AAF.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SFOR.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  53 of 53 completed
# [*********************100%***********************]  53 of 53 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  68 of 68 completed
#
# 9 Failed downloads:
# - WRKS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - UPGS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - TRN.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - TIFS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - STU.L: No data found, symbol may be delisted
# - BOWL.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AML.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - XPS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - WOSG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  53 of 53 completed
# [*********************100%***********************]  53 of 53 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  30 of 30 completed
#
# 2 Failed downloads:
# - CCEP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BAKK.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  29 of 29 completed
# [*********************100%***********************]  29 of 29 completed
# C:\Users\vgole\AppData\Local\Temp\ipykernel_25432\65998627.py:250: RuntimeWarning: invalid value encountered in double_scalars
#   ar_returns_rank.iat[ar_returns_rank.index.get_loc('t-rank'),i] = ar_returns_rank.iat[0,i]/ar_returns_rank.iat[1,i]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  75 of 75 completed
#
# 14 Failed downloads:
# - WCAT.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BLOE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - HBR.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ORCA.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - PPP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - URAH.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - VVO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ANGS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - LBE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ENOG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - I3E.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AT.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CORO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - KIST.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  60 of 60 completed
# [*********************100%***********************]  60 of 60 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  101 of 101 completed
#
# 12 Failed downloads:
# - MNG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SSON.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - FCH.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - QLT.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - EGL.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SBRE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ASLI.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AMGO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CAY.L: No data found, symbol may be delisted
# - AJB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - IHP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - HFEL.L: Duplicate key 1525244400
# [*********************100%***********************]  84 of 84 completed
# [*********************100%***********************]  84 of 84 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  101 of 101 completed
#
# 32 Failed downloads:
# - ABDX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - MGP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BVX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - VRCI.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CBX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SBTX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CREO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - DXRX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - FAB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CIZ.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - GENF.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - 4BB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - INHC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - POLB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - NCYT.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - KOO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AREC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SPEC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - GENI.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ROQ.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SBI.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SENS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - APTA.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ONT.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BELL.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - OKYO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - DEST.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - OCTP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ARIX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - OBD.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - KNB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CTEC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  62 of 62 completed
# [*********************100%***********************]  62 of 62 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  88 of 88 completed
#
# 4 Failed downloads:
# - KGH.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - LUCE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BIFF.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - DWF.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  84 of 84 completed
# [*********************100%***********************]  84 of 84 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  38 of 38 completed
#
# 1 Failed download:
# - GPOR.L: No data found, symbol may be delisted
# [*********************100%***********************]  35 of 35 completed
# [*********************100%***********************]  35 of 35 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  142 of 142 completed
#
# 36 Failed downloads:
# - WPS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BKS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - OTAQ.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ECSC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - GETB.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SKL.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SFTL.IL: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - MTEC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - VDTK.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CLX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - LST.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ATG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SYME.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ALFA.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CCS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - INSG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ITIM.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - WISE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - SAAS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - GRC.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - INX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AWE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - TPX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BYIT.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - 4GBL.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - PTRO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - AOM.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - BIG.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - FNX.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - MODE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CSFS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ESYS.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - DARK.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - LOOP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - PBEE.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - TWD.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  100 of 100 completed
# [*********************100%***********************]  100 of 100 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  20 of 20 completed
#
# 7 Failed downloads:
# - MAST.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - NZI.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ETP.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - PNPL.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - GLO.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - CPH2.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# - ATOM.L: Data doesn't exist for startDate = 1420066800, endDate = 1465423200
# [*********************100%***********************]  13 of 13 completed
# [*********************100%***********************]  13 of 13 completed

# %%
combined_data.transpose().to_csv('123.csv', mode='a')

# %%
combined_data.iloc[:,:]
f"{str(caar.iloc[7:13,3])}({caar.iloc[7:13,4]})"
# Out:
# '-3    0.088327\n-2    0.095557\n-1    0.077454\n 0    0.041725\n 1    0.067198\n 2    0.082160\nName: p-value, dtype: float64(-3     \n-2     \n-1     \n 0    *\n 1     \n 2     \nName: Significance, dtype: object)'

# %%
caar.trans
# Out:
#                    -10       -9        -8        -7        -6        -5   \
# CAAR         -0.000092  0.001051 -0.017501 -0.019345 -0.028736 -0.030303
# Variance      0.000074  0.000148  0.000223  0.000297  0.000371  0.000445
# t-stat       -0.010694   0.08629 -1.173217  -1.12311 -1.492157  -1.43642
# p-value       0.495734  0.534382  0.120354  0.130695  0.067829  0.075441
# Significance
# 95% CI       -0.014166 -0.020034 -0.024536 -0.028332 -0.031676   -0.0347
# 99% CI       -0.020035 -0.028334 -0.034702 -0.040071 -0.044801 -0.049077
#
#                    -4        -3        -2        -1         0         1   \
# CAAR         -0.035989 -0.032913 -0.033777 -0.038739 -0.049445 -0.044662
# Variance      0.000519  0.000593  0.000668  0.000742  0.000816   0.00089
# t-stat       -1.579398 -1.351132 -1.307288 -1.422407 -1.731009  -1.49699
# p-value       0.057122  0.088327  0.095557  0.077454  0.041725  0.067198
# Significance                                                 *
# 95% CI        -0.03748 -0.040068 -0.042498 -0.044797 -0.046984 -0.049073
# 99% CI       -0.053009 -0.056669 -0.060106 -0.063358  -0.06645 -0.069405
#
#                     2         3         4         5         6         7   \
# CAAR         -0.043184  -0.03668 -0.002105  -0.00362 -0.002939 -0.004674
# Variance      0.000964  0.001038  0.001113  0.001187  0.001261  0.001335
# t-stat       -1.390688 -1.138259 -0.063106 -0.105094 -0.082759 -0.127922
# p-value        0.08216  0.127506  0.474841  0.458151  0.467022  0.449105
# Significance
# 95% CI       -0.051077 -0.053005 -0.054865 -0.056665 -0.058408 -0.060102
# 99% CI       -0.072239 -0.074966 -0.077597 -0.080142 -0.082608 -0.085003
#
#                     8         9         10        11        12        13  \
# CAAR          0.001925 -0.009077  -0.01046  0.020135  0.013171   0.01757
# Variance      0.001409  0.001483  0.001558  0.001632  0.001706   0.00178
# t-stat        0.051281  -0.23566 -0.265028  0.498446  0.318893   0.41643
# p-value       0.520449  0.406848  0.395494  0.690915  0.625096  0.661452
# Significance
# 95% CI       -0.061749 -0.063353 -0.064917 -0.066445 -0.067938   -0.0694
# 99% CI       -0.087332 -0.089601 -0.091814 -0.093975 -0.096087 -0.098153
#
#                     14        15        16        17        18        19  \
# CAAR          0.007277  0.013671  0.013654  0.021049  0.035315  0.022943
# Variance      0.001854  0.001929  0.002003  0.002077  0.002151  0.002225
# t-stat        0.168981  0.311313  0.305118  0.461879  0.761433  0.486366
# p-value       0.567094  0.622219  0.619862  0.677916  0.776801  0.686646
# Significance
# 95% CI       -0.070831 -0.072233 -0.073609  -0.07496 -0.076287 -0.077591
# 99% CI       -0.100177 -0.102161 -0.104107 -0.106018 -0.107894 -0.109739
#
#                     20        21        22        23        24        25  \
# CAAR          0.024878  0.027001  0.020638  0.019511  0.017928  0.008493
# Variance      0.002299  0.002374  0.002448  0.002522  0.002596   0.00267
# t-stat        0.518819  0.554208  0.417153  0.388529  0.351869  0.164358
# p-value       0.698057  0.710282  0.661717  0.651188  0.637532  0.565275
# Significance
# 95% CI       -0.078874 -0.080136 -0.081378 -0.082602 -0.083808 -0.084997
# 99% CI       -0.111553 -0.113338 -0.115095 -0.116826 -0.118531 -0.120213
#
#                     26        27        28        29        30
# CAAR          0.011522  0.011806  0.005854  0.004821  -0.00147
# Variance      0.002744  0.002819  0.002893  0.002967  0.003041
# t-stat        0.219934  0.222366  0.108836  0.088517 -0.026663
# p-value       0.587039  0.587986  0.543334  0.535267  0.489364
# Significance
# 95% CI       -0.086169 -0.087326 -0.088467 -0.089594 -0.090708
# 99% CI       -0.121871 -0.123507 -0.125121 -0.126715 -0.128289
